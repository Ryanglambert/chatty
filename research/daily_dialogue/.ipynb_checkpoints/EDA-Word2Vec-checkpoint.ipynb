# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

# %load_ext autoreload
# %autoreload 2

import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd
import seaborn as sns
import textblob
import gensim
import spacy
import os

import data
import plot
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# Takes a 5 minutes the first time, but use `use_cached` afterward so you don't have to wait in the future.

# %%
train, train_vecs, test, test_vecs = data.get_data(use_cached=True)

train['utter_len'] = train['utter'].map(lambda x: len(x.split(' ')))

train['has_question_mark'] = train['utter'].map(lambda x: 1 if'?' in x.split(' ') else 0)
train = pd.concat([train, data.get_lags(train[['has_question_mark']], lag_range=[1])], axis=1)
# Out:
# Using Cached

# %%
LAG_MASK = ['act', 'emo', 'polarity', 'subjectivity']
train_lags = data.get_lags(train[LAG_MASK], lag_range=[1, 2])

# %% [markdown]
# Is first utterance?

# %% [markdown]
# ### Classify Dialogue Acts

# %% [markdown]
# ### First shot

# %%
from sklearn.metrics import precision_recall_curve, confusion_matrix
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier

from chatty.utils import dd_encodings

ACT_MASK = train['act'].notnull() & train['has_question_mark_t-1'].notnull()

assert train['act'][train['act'].notnull()].shape[0] \
      == train_vecs[train['act'].notnull()].shape[0]

TRAIN_MASK = ['first_utterance',
              'subjectivity',
              'utter_len',
              'has_question_mark',
              'has_question_mark_t-1']

X = np.concatenate((train_vecs,
                    train[TRAIN_MASK].values),
                   axis=1)[ACT_MASK]
y = train['act'][ACT_MASK]

# %%
results = data.cv_stratified_shuffle(X, y,
                                     RandomForestClassifier(n_jobs=-1),
                                     splits=5)
# Out:
# Training
# Training
# Training
# Training
# Training

# %%
title = "RandomForest"
plot.plot_prec_rec(results, title)
le = LabelEncoder()
le.fit(results['classes'])
cm = confusion_matrix(le.transform(np.concatenate(results['y_true'])),
                      np.argmax(np.concatenate(results['y_proba']), axis=1))
plt.figure()
plot.plot_confusion_matrix(cm, le.classes_, normalize=True, title=title);
# Out:
# Normalized confusion matrix
# [[0.27979562 0.0947462  0.59246918 0.032989  ]
#  [0.04072916 0.39440165 0.38677446 0.17809473]
#  [0.05075937 0.05890812 0.87120945 0.01912306]
#  [0.00651681 0.06809596 0.05983189 0.86555535]]

# %% [markdown]
# ### 20 and 21 are duplicates

# %%
np.concatenate(results['y_proba']).shape
# Out:
# (82928, 4)

# %%
y_proba = pd.DataFrame(np.concatenate(results['y_proba']))
y_true = pd.concat(results['y_true'])
y_proba.index = y_true.index
y_proba.columns = le.classes_

# %%
df = train.join(y_proba)

# %%
df[['utter', 'act'] + list(y_proba.columns)]
# Out:
#                                                       utter         act  \
# conv
# 0     0                               The kitchen stinks .    directive
#       1                       I'll throw out the garbage .   commissive
# 1     0   So Dick , how about getting some coffee for to...   directive
#       1    Coffee ? I don ’ t honestly like that kind of...  commissive
#       2    Come on , you can at least try a little , bes...   directive
#       3    What ’ s wrong with that ? Cigarette is the t...      inform
#       4                                Not for me , Dick .       inform
# 2     0   Are things still going badly with your housegu...    question
#       1    Getting worse . Now he ’ s eating me out of h...      inform
#       2    Leo , I really think you ’ re beating around ...   directive
#       3    You ’ re right . Everything is probably going...  commissive
# 3     0                   Would you mind waiting a while ?    directive
#       1                       Well , how long will it be ?     question
#       2    I'm not sure . But I'll get a table ready as ...      inform
#       3                                  OK . We'll wait .       inform
# 4     0   Are you going to the annual party ? I can give...   directive
#       1    Thanks a lot . That's the favor I was going t...  commissive
#       2                             The pleasure is mine .       inform
# 5     0   Isn ’ t he the best instructor ? I think he ’ ...    question
#       1       I swear , I ’ m going to kill you for this .       inform
#       2    What ’ s wrong ? Didn ’ t you think it was fu...    question
#       3    Oh , yeah ! I had a blast ! I love sweating l...      inform
#       4    Oh , no , get off it . It wasn ’ t such a kil...   directive
#       5                       I am wiped out . Thank you .   commissive
#       6    Look , next time get yourself some comfy shoe...   directive
#       7            Never ! But thank you for inviting me .   commissive
#       8    Come on . You ’ ll feel better after we hit t...   directive
# 6     0   Can I take your order now or do you still want...    question
#       1    Well , I want a fillet steak , medium , but m...    question
#       2    Certainly . How about spaghetti with clams an...   directive
# ...                                                     ...         ...
# 13114 0   Lindsay Tipping gave me your name as a referen...      inform
#       1    Lindsay , of course , I will be more than hap...      inform
#       2      How long was she employed with your company ?     question
#       3    She freelanced with us for 3 years . She was ...      inform
#       4    Freelance , hmm . How do you think she will m...    question
#       5    She ’ s a consummate professional and a team-...      inform
# 13115 0   The consignments of chemical instruments have ...   directive
#       1                          Is there anything wrong ?     question
#       2    We bought 1,000 sets of chemical instruments ...      inform
#       3    It's hard for us to believe it . Our instrume...    question
#       4    Here is the survey report from a well-known p...      inform
#       5    Well . According to the contract , we are res...   directive
#       6    Forty faulty instruments means that 4 % are n...   directive
#       7    I am sorry about the quality problem , but I ...   directive
#       8    All right . In that case we are still willing...  commissive
# 13117 0    May I ask you a few questions about insurance ?    directive
#       1                                              Yes .   commissive
#       2    Now we've given a CIF Shanghai price for some...    question
#       3    Well . Obviously , you won ’ t want All Risks...      inform
#       4                                          Why not ?     question
#       5    Because they aren ’ t delicate goods and won ...      inform
#       6    Then am I right in understanding that FPA doe...      inform
#       7    That's right . On the other hand , a WA polic...      inform
#       8    Are there any other clauses in marine policie...    question
#       9    Oh , lots of them . For instance , War Risks ...      inform
#       10   Well , thank you very much for all that infor...   directive
#       11            Are you going to make an offer today ?     question
#       12   Yes . My customer is in urgent need of the st...      inform
#       13              Ok , I'll get this rate right away .   commissive
#       14                                       Thank you .       inform
#
#           commissive  directive    inform  question
# conv
# 0     0          NaN        NaN       NaN       NaN
#       1     0.200000   0.200000  0.400000  0.200000
# 1     0          NaN        NaN       NaN       NaN
#       1     0.800000   0.000000  0.000000  0.200000
#       2     0.000000   0.800000  0.100000  0.100000
#       3     0.000000   0.000000  0.000000  1.000000
#       4     0.000000   0.100000  0.900000  0.000000
# 2     0          NaN        NaN       NaN       NaN
#       1     0.000000   0.000000  1.000000  0.000000
#       2     0.100000   0.100000  0.800000  0.000000
#       3     0.800000   0.000000  0.200000  0.000000
# 3     0          NaN        NaN       NaN       NaN
#       1     0.000000   0.000000  0.100000  0.900000
#       2     0.200000   0.400000  0.300000  0.100000
#       3     0.400000   0.200000  0.200000  0.200000
# 4     0          NaN        NaN       NaN       NaN
#       1     0.300000   0.100000  0.500000  0.100000
#       2     0.200000   0.000000  0.700000  0.100000
# 5     0          NaN        NaN       NaN       NaN
#       1     0.400000   0.200000  0.300000  0.100000
#       2     0.000000   0.000000  0.100000  0.900000
#       3     0.000000   0.100000  0.800000  0.100000
#       4     0.100000   0.100000  0.800000  0.000000
#       5     0.000000   0.000000  1.000000  0.000000
#       6     0.000000   0.100000  0.100000  0.800000
#       7     0.200000   0.000000  0.800000  0.000000
#       8     0.200000   0.100000  0.700000  0.000000
# 6     0          NaN        NaN       NaN       NaN
#       1     0.150000   0.300000  0.250000  0.300000
#       2     0.000000   0.200000  0.700000  0.100000
# ...              ...        ...       ...       ...
# 13114 0          NaN        NaN       NaN       NaN
#       1     0.100000   0.530000  0.250000  0.120000
#       2     0.000000   0.300000  0.200000  0.500000
#       3     0.000000   0.100000  0.900000  0.000000
#       4     0.000000   0.300000  0.000000  0.700000
#       5     0.100000   0.200000  0.700000  0.000000
# 13115 0          NaN        NaN       NaN       NaN
#       1     0.000000   0.000000  0.000000  1.000000
#       2     0.000000   0.100000  0.700000  0.200000
#       3     0.000000   0.200000  0.200000  0.600000
#       4     0.000000   0.400000  0.500000  0.100000
#       5     0.100000   0.200000  0.700000  0.000000
#       6     0.200000   0.200000  0.600000  0.000000
#       7     0.200000   0.200000  0.500000  0.100000
#       8     0.200000   0.200000  0.500000  0.100000
# 13117 0          NaN        NaN       NaN       NaN
#       1     0.081614   0.000000  0.910887  0.007499
#       2     0.050000   0.100000  0.150000  0.700000
#       3     0.000000   0.200000  0.700000  0.100000
#       4     0.026589   0.023199  0.000000  0.950213
#       5     0.200000   0.200000  0.500000  0.100000
#       6     0.000000   0.100000  0.700000  0.200000
#       7     0.133333   0.266667  0.600000  0.000000
#       8     0.133333   0.000000  0.200000  0.666667
#       9     0.100000   0.000000  0.700000  0.200000
#       10    0.000000   0.300000  0.200000  0.500000
#       11    0.100000   0.300000  0.100000  0.500000
#       12    0.100000   0.300000  0.600000  0.000000
#       13    0.400000   0.200000  0.400000  0.000000
#       14    0.234833   0.000000  0.765167  0.000000
#
# [95047 rows x 6 columns]
