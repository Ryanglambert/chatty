# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

# %load_ext autoreload
# %autoreload 2

import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd
import seaborn as sns
import textblob
import gensim
import spacy
import os

import data
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# Takes a 5 minutes the first time, but use `use_cached` afterward so you don't have to wait in the future.

# %%
train, train_vecs, test, test_vecs = data.get_data(use_cached=False)
# Out:
# Not Using Cached
# Parsing Labeled Conversations
# /Users/ryan/miniconda3/envs/chatty/lib/python3.6/site-packages/numpy/core/fromnumeric.py:52: FutureWarning: 'argmin' is deprecated, use 'idxmin' instead. The behavior of 'argmin'
# will be corrected to return the positional minimum in the future.
# Use 'series.values.argmin' to get the position of the minimum now.
#   return getattr(obj, method)(*args, **kwds)
# /Users/ryan/miniconda3/envs/chatty/lib/python3.6/site-packages/numpy/core/fromnumeric.py:52: FutureWarning: 'argmax' is deprecated, use 'idxmax' instead. The behavior of 'argmax'
# will be corrected to return the positional maximum in the future.
# Use 'series.values.argmax' to get the position of the maximum now.
#   return getattr(obj, method)(*args, **kwds)
# Making word embeddings

# %% [markdown]
# # Goals of Exploration
#
# - Use word2vec as implemented in gensim
# - Classify the Sentiment
# - Classify dialogue action
# - Predict the next sentiment from:
#     - Previous sentiments
#         - including both persons
#     - Previous dialogue actions
#         - including both persons

# %% [markdown]
# Should put this into a module so we don't take up so much memory

# %%
train
# Out:
#           person                                              utter  \
# conv
# 0    0  person_a                              The kitchen stinks .
#      1  person_b                      I'll throw out the garbage .
# 1    0  person_a  So Dick , how about getting some coffee for to...
#      1  person_b   Coffee ? I don ’ t honestly like that kind of...
#      2  person_a   Come on , you can at least try a little , bes...
#
#                act         emo  polarity  subjectivity          topic  \
# conv
# 0    0   directive     disgust  -0.60000          0.50  ordinary_life
#      1  commissive  no_emotion   0.00000          0.00  ordinary_life
# 1    0   directive   happiness   0.00000          0.00  ordinary_life
#      1  commissive     disgust   0.60000          0.90  ordinary_life
#      2   directive  no_emotion  -0.24375          0.45  ordinary_life
#
#         biggest_drawup  biggest_drawdown
# conv
# 0    0         0.00000           0.00000
# ...

# %%
LAG_MASK = ['act', 'emo', 'polarity', 'subjectivity']

# %%
def get_lags(df, lag_range=[1, 2]):
    "Gets lags values within conversation"
    groupby_conv = df.groupby(df.index.get_level_values(0))
    train_lags = pd.concat([groupby_conv.shift(i) for i in lag_range], axis=1)
    new_cols = []
    for col in df.columns:
        for lag_num in lag_range:
            new_cols.append(col + "_t-" + str(lag_num))
    train_lags.columns = new_cols
    return train_lags

# %%
get_lags(train[LAG_MASK], lag_range=[1, 2])
# Out:
#              act_t-1     act_t-2   emo_t-1   emo_t-2 polarity_t-1  \
# conv
# 0     0          NaN         NaN       NaN       NaN          NaN
#       1    directive     disgust -0.600000  0.500000          NaN
# 1     0          NaN         NaN       NaN       NaN          NaN
#       1    directive   happiness  0.000000  0.000000          NaN
#       2   commissive     disgust  0.600000  0.900000    directive
#       3    directive  no_emotion -0.243750  0.450000   commissive
#       4       inform       anger -0.550000  0.900000    directive
# 2     0          NaN         NaN       NaN       NaN          NaN
#       1     question  no_emotion -0.700000  0.666667          NaN
#       2       inform       anger -0.032799  0.367201     question
#       3    directive  no_emotion  0.311111  0.247222       inform
# 3     0          NaN         NaN       NaN       NaN          NaN
#       1    directive  no_emotion  0.000000  0.000000          NaN
# ...

# %%
get_lags(train[LAG_MASK], lag_range=[1, 2, 3])
# Out:
#              act_t-1     act_t-2   act_t-3   emo_t-1     emo_t-2     emo_t-3  \
# conv
# 0     0          NaN         NaN       NaN       NaN         NaN         NaN
#       1    directive     disgust -0.600000  0.500000         NaN         NaN
# 1     0   commissive  no_emotion  0.000000  0.000000   directive     disgust
#       1    directive   happiness  0.000000  0.000000  commissive  no_emotion
#       2   commissive     disgust  0.600000  0.900000   directive   happiness
#       3    directive  no_emotion -0.243750  0.450000  commissive     disgust
#       4       inform       anger -0.550000  0.900000   directive  no_emotion
# 2     0       inform  no_emotion  0.000000  0.000000      inform       anger
#       1     question  no_emotion -0.700000  0.666667      inform  no_emotion
#       2       inform       anger -0.032799  0.367201    question  no_emotion
#       3    directive  no_emotion  0.311111  0.247222      inform       anger
# ...

# %%
train_lags
# Out:
#              act_t-1     act_t-2   emo_t-1   emo_t-2 polarity_t-1  \
# conv
# 0     0          NaN         NaN       NaN       NaN          NaN
#       1    directive     disgust -0.600000  0.500000          NaN
# 1     0   commissive  no_emotion  0.000000  0.000000    directive
#       1    directive   happiness  0.000000  0.000000   commissive
#       2   commissive     disgust  0.600000  0.900000    directive
#       3    directive  no_emotion -0.243750  0.450000   commissive
#       4       inform       anger -0.550000  0.900000    directive
# 2     0       inform  no_emotion  0.000000  0.000000       inform
#       1     question  no_emotion -0.700000  0.666667       inform
#       2       inform       anger -0.032799  0.367201     question
#       3    directive  no_emotion  0.311111  0.247222       inform
# 3     0   commissive  no_emotion  0.285714  0.535714    directive
#       1    directive  no_emotion  0.000000  0.000000   commissive
# ...

# %%
for col in LAG_MASK:
    for l in range(1, 1 + num_lags):
        print(str(l) + "_" + col)
# Out:
# 1_act
# 2_act
# 1_emo
# 2_emo
# 1_polarity
# 2_polarity
# 1_subjectivity
# 2_subjectivity

# %%
pd.concat([], )

# %%
train_lags
# Out:
#                  act         emo  polarity  subjectivity         act  \
# conv
# 0     0          NaN         NaN       NaN           NaN         NaN
#       1    directive     disgust -0.600000      0.500000         NaN
# 1     0   commissive  no_emotion  0.000000      0.000000   directive
#       1    directive   happiness  0.000000      0.000000  commissive
#       2   commissive     disgust  0.600000      0.900000   directive
#       3    directive  no_emotion -0.243750      0.450000  commissive
#       4       inform       anger -0.550000      0.900000   directive
# 2     0       inform  no_emotion  0.000000      0.000000      inform
#       1     question  no_emotion -0.700000      0.666667      inform
#       2       inform       anger -0.032799      0.367201    question
#       3    directive  no_emotion  0.311111      0.247222      inform
# 3     0   commissive  no_emotion  0.285714      0.535714   directive
# ...
