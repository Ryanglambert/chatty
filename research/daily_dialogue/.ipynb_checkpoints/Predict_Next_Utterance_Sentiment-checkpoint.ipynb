# %% [markdown]
# # Go straight to predicting the sentiment of the next utterance

# %%
from spacy import displacy

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

# %load_ext autoreload
# %autoreload 2

import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd
import spacy
import os
from functools import partial

import data
import plot

from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import BernoulliNB
from sklearn.ensemble import GradientBoostingClassifier, RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier

from chatty.utils import tokens

train, train_vecs, test, test_vecs = data.get_data(use_cached=True)

train['utter_len'] = train['utter'].map(lambda x: len(x.split(' ')))

train['has_question_mark'] = train['utter'].map(lambda x: 1 if'?' in x.split(' ') else 0)
train = pd.concat([train, data.get_lags(train[['has_question_mark']], lag_range=[1])], axis=1)
train[['utter_t-3', 'utter_t-2', 'utter_t-1']] = data.get_lags(train[['utter']], lag_range=[3, 2, 1])
# Out:
# <style>.container { width:100% !important; }</style>
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Using Cached

# %%
ACT_MASK = train['act'].notnull() & train['has_question_mark_t-1'].notnull()

assert train['act'][train['act'].notnull()].shape[0] \
      == train_vecs[train['act'].notnull()].shape[0]

TRAIN_MASK = ['first_utterance',
              'subjectivity',
              'utter_len',
              'has_question_mark',
              'has_question_mark_t-1']

X = np.concatenate((train_vecs,
                    train[TRAIN_MASK].values),
                   axis=1)[ACT_MASK]
y = train['act'][ACT_MASK]

# %% [markdown]
# ### Predict next emo directly from Pipeline RandomForest on words and pos

# %%
from sklearn.pipeline import FeatureUnion
from imblearn.pipeline import Pipeline
from imblearn.over_sampling import SMOTE, RandomOverSampler

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.ensemble import RandomForestClassifier


from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier

from chatty.utils import tokens
# %reload_ext chatty.utils.tokens


vocab = np.array(tokens.load_vocab('subjects_dependency_pos', 'word_ngram_2')['vocab'])


SPLITTER = "*^"
def vocab_splitter(tokens: str):
    return tokens.split(SPLITTER)

LAG_MASK = ['vocab_t-3', 'vocab_t-2', 'vocab_t-1']

train['vocab'] = pd.Series(vocab, index=train.index).map(lambda x: SPLITTER.join(x))
train[LAG_MASK] = data.get_lags(train[['vocab']], lag_range=[3, 2, 1])

ACT_MASK = train['emo'].notnull() \
         & train['vocab_t-1'].notnull() \
         & train['vocab_t-2'].notnull() \
         & train['vocab_t-3'].notnull()

assert train['emo'][train['emo'].notnull()].shape[0] \
      == train_vecs[train['emo'].notnull()].shape[0]


X = train[LAG_MASK][ACT_MASK].values

y = train['emo'][ACT_MASK].values

# %%
from chatty.utils.vectorize import CountVectorizerColumnN

fu = FeatureUnion([('vocab_t-3', CountVectorizerColumnN(analyzer=vocab_splitter, colnum=0)),
                   ('vocab_t-2', CountVectorizerColumnN(analyzer=vocab_splitter, colnum=1)),
                   ('vocab_t-1', CountVectorizerColumnN(analyzer=vocab_splitter, colnum=2))])

clf = Pipeline([
    ('feature_union_countvecs', fu),
    ('random', RandomOverSampler('minority')),
    ('RandomForest', RandomForestClassifier(n_jobs=-1))
])

# %%
results = data.cv_stratified_shuffle(X, y,
                                     clf,
                                     splits=2)
# Out:
# Training
# Training
# Training
# Training
# Training

# %%
plot.plot_prec_rec(results, "RandomForest", normalize_confusion_matrix=True)

# %% [markdown]
# ### Gradient Boosted Classifier

# %%
from sklearn.pipeline import FeatureUnion
from imblearn.pipeline import Pipeline
from imblearn.over_sampling import SMOTE, RandomOverSampler
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier

from chatty.utils import tokens
# %reload_ext chatty.utils.tokens


vocab = np.array(tokens.load_vocab('subjects_dependency_pos', 'word_ngram_2')['vocab'])


SPLITTER = "*^"
def vocab_splitter(tokens: str):
    return tokens.split(SPLITTER)

LAG_MASK = ['vocab_t-3', 'vocab_t-2', 'vocab_t-1']

train['vocab'] = pd.Series(vocab, index=train.index).map(lambda x: SPLITTER.join(x))
train[LAG_MASK] = data.get_lags(train[['vocab']], lag_range=[3, 2, 1])

ACT_MASK = train['emo'].notnull() \
         & train['vocab_t-1'].notnull() \
         & train['vocab_t-2'].notnull() \
         & train['vocab_t-3'].notnull()

assert train['emo'][train['emo'].notnull()].shape[0] \
      == train_vecs[train['emo'].notnull()].shape[0]


X = train[LAG_MASK][ACT_MASK].values

y = train['emo'][ACT_MASK].values

# %%
from chatty.utils.vectorize import CountVectorizerColumnN

fu = FeatureUnion([('vocab_t-3', CountVectorizerColumnN(analyzer=vocab_splitter, colnum=0)),
                   ('vocab_t-2', CountVectorizerColumnN(analyzer=vocab_splitter, colnum=1)),
                   ('vocab_t-1', CountVectorizerColumnN(analyzer=vocab_splitter, colnum=2))])

clf = Pipeline([
    ('feature_union_countvecs', fu),
    ('random', RandomOverSampler('minority')),
    ('RandomForest', GradientBoostingClassifier())
])

# %%
results = data.cv_stratified_shuffle(X, y,
                                     clf,
                                     splits=2)
# Out:
# Training
# Training

# %%
plot.plot_prec_rec(results, "GradientBoostingClassifier", normalize_confusion_matrix=True)

# %% [markdown]
# ### RandomForest with unigram lemmas, bigram lemmas, and subjects dependency grams

# %%
from sklearn.pipeline import FeatureUnion
from imblearn.pipeline import Pipeline
from imblearn.over_sampling import SMOTE, RandomOverSampler
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier

from chatty.utils import tokens
# %reload_ext chatty.utils.tokens


vocab = np.array(tokens.load_vocab('lemma_', 'lemma_ngram_2', 'pos', 'pos_ngram_2')['vocab'])

SPLITTER = "*^"
def vocab_splitter(tokens: str):
    return tokens.split(SPLITTER)

LAG_MASK = ['vocab_t-3', 'vocab_t-2', 'vocab_t-1']

train['vocab'] = pd.Series(vocab, index=train.index).map(lambda x: SPLITTER.join(x))
train[LAG_MASK] = data.get_lags(train[['vocab']], lag_range=[3, 2, 1])

ACT_MASK = train['emo'].notnull() \
         & train['vocab_t-1'].notnull() \
         & train['vocab_t-2'].notnull() \
         & train['vocab_t-3'].notnull()

assert train['emo'][train['emo'].notnull()].shape[0] \
      == train_vecs[train['emo'].notnull()].shape[0]


X = train[LAG_MASK][ACT_MASK].values
y = train['emo'][ACT_MASK].values

# %%
from chatty.utils.vectorize import CountVectorizerColumnN

fu = FeatureUnion([('vocab_t-3', CountVectorizerColumnN(analyzer=vocab_splitter, colnum=0)),
                   ('vocab_t-2', CountVectorizerColumnN(analyzer=vocab_splitter, colnum=1)),
                   ('vocab_t-1', CountVectorizerColumnN(analyzer=vocab_splitter, colnum=2))])

clf = Pipeline([
    ('feature_union_countvecs', fu),
    ('random', RandomOverSampler('minority')),
    ('RandomForest', RandomForestClassifier(n_jobs=-1, verbose=True))
])

results = data.cv_stratified_shuffle(X, y,
                                     clf,
                                     splits=2)
# Out:
# Training
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:    9.3s finished
# [Parallel(n_jobs=4)]: Done  10 out of  10 | elapsed:    0.2s finished
# Training
# [Parallel(n_jobs=-1)]: Done  10 out of  10 | elapsed:   10.2s finished
# [Parallel(n_jobs=4)]: Done  10 out of  10 | elapsed:    0.2s finished

# %%
plot.plot_prec_rec(results, "RandomForest", normalize_confusion_matrix=True)

# %%
names = results['models'][0].named_steps['feature_union_countvecs'].get_feature_names()

importances = results['models'][0].named_steps['RandomForest'].feature_importances_

# %%
len(names)
# Out:
# 59382

# %%
len(importances)
# Out:
# 59382

# %%
list(filter(lambda x: x[0] < 25, enumerate(sorted(zip(names, importances), key=lambda x: x[1], reverse=True))))
# Out:
# [(0, ('vocab_t-3__LEMMA_what', 0.010402214228995581)),
#  (1, ('vocab_t-1__LEMMA_.', 0.009138929225965316)),
#  (2, ('vocab_t-1__LEMMA_sir', 0.009117491421993201)),
#  (3, ('vocab_t-1__LEMMA_-PRON-', 0.00849363064079808)),
#  (4, ('vocab_t-2__LEMMA_!', 0.008058605876444986)),
#  (5, ('vocab_t-1__LEMMA_be', 0.007756998729782284)),
#  (6, ('vocab_t-3__LEMMA_.', 0.006732092152260979)),
#  (7, ('vocab_t-2__LEMMA_1234', 0.0059781491783237)),
#  (8, ('vocab_t-2__LEMMA_-PRON-', 0.005783989822506571)),
#  (9, ('vocab_t-1__LEMMA_all', 0.005724895486715521)),
#  (10, ('vocab_t-1__LEMMA_okay', 0.005315206441926257)),
#  (11, ('vocab_t-1__LEMMA_,', 0.0051825049646208364)),
#  (12, ('vocab_t-3__LEMMA_over', 0.00517764053310614)),
#  (13,
#   ('vocab_t-2__ROOT_call_ROOTPOS_VERB_POS_NOUN_DEP_dobj',
#    0.005150586553324566)),
#  (14, ('vocab_t-1__LEMMA_that', 0.005129996619028592)),
#  (15, ('vocab_t-2__LEMMA_not', 0.004868108085812253)),
#  (16, ('vocab_t-1__LEMMA_reservation', 0.004710623365975612)),
#  (17,
#   ('vocab_t-3__ROOT_is_ROOTPOS_VERB_POS_PRON_DEP_nsubj',
#    0.004597460534281018)),
#  (18, ('vocab_t-3__LEMMA_mom', 0.004490657227120828)),
#  (19, ('vocab_t-2__LEMMA_cd', 0.004479495191412446)),
#  (20, ('vocab_t-1__LEMMA_?', 0.004373198574769376)),
#  (21, ('vocab_t-3__LEMMA_,', 0.004201615787695356)),
#  (22, ('vocab_t-2__LEMMA_think', 0.00417461149062962)),
#  (23,
#   ('vocab_t-3__ROOT_happened_ROOTPOS_VERB_POS_NOUN_DEP_nsubj',
#    0.0039598284843233005)),
#  (24, ('vocab_t-3__LEMMA_to', 0.003956892705692127))]

# %%
plt.plot(sorted(importances, reverse=True))
plt.xlim(0, 2000)
# Out:
# (0, 2000)

# %%
# def root_lemma_tok_pos():
#     pass

# %%
import spacy
nlp = spacy.load("en")

# %%
doc = nlp(train['utter'].iloc[100])

# %%
doc
# Out:
# I think I going to need some iced water too . Is there an extra charge for that ?

# %%
list(tokens.subjects_dependency_pos(doc))
# Out:
# ['ROOT_re_ROOTPOS_VERB_POS_PUNCT_DEP_nsubj',
#  'ROOT_going_ROOTPOS_VERB_POS_NOUN_DEP_nsubj',
#  'ROOT_going_ROOTPOS_VERB_POS_NOUN_DEP_pobj',
#  'ROOT_keep_ROOTPOS_VERB_POS_PRON_DEP_nsubj']

# %%
a = list(doc.sents)
a
# Out:
# [I think I going to need some iced water too .,
#  Is there an extra charge for that ?]

# %%
b = a[0]
b
# Out:
# I think I going to need some iced water too .

# %%
c = list(b.root.children)
c
# Out:
# [I, going, .]

# %%
d = c[1]
d
# Out:
# going

# %%
e_0 = list(d.children)[0]
e_1 = list(d.children)[1]
print(e_0, e_1)
# Out:
# I need

# %%
displacy.render(doc, jupyter=True)
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="0" class="displacy" width="3025" height="487.0" style="max-width: none; height: 487.0px; color: #000000; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">I</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">think</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">I</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">going</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">need</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">some</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">iced</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">water</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">too .</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">Is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="1975">there</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">an</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2325">extra</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2500">charge</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2675">for</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="2850">that ?</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">DET</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-0" stroke-width="2px" d="M70,352.0 C70,264.5 210.0,264.5 210.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-0" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,354.0 L62,342.0 78,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-1" stroke-width="2px" d="M420,352.0 C420,264.5 560.0,264.5 560.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-1" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,354.0 L412,342.0 428,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-2" stroke-width="2px" d="M245,352.0 C245,177.0 565.0,177.0 565.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-2" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">ccomp</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M565.0,354.0 L573.0,342.0 557.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-3" stroke-width="2px" d="M770,352.0 C770,264.5 910.0,264.5 910.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-3" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M770,354.0 L762,342.0 778,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-4" stroke-width="2px" d="M595,352.0 C595,177.0 915.0,177.0 915.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-4" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">xcomp</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M915.0,354.0 L923.0,342.0 907.0,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-5" stroke-width="2px" d="M1120,352.0 C1120,177.0 1440.0,177.0 1440.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-5" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1120,354.0 L1112,342.0 1128,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-0-6" stroke-width="2px" d="M1295,352.0 C1295,264.5 1435.0,264.5 1435.0,352.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-0-6" class="displacy-label" startOffset="50%" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1295,354.0 L1287,342.0 1303,342.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy

# %%
list(e_0.children)
# Out:
# []

# %%
list(e_1.children)
# Out:
# [to, water, too]

# %%
for sent in doc.sents:
    print(sent.root)
# Out:
# You
# re
# going
# I
# ’
# keep

# %% [markdown]
# ### detailed scrutiny

# %%
train.columns
# Out:
# Index(['person', 'utter', 'act', 'emo', 'polarity', 'subjectivity', 'topic',
#        'first_utterance', 'biggest_drawup', 'biggest_drawdown', 'utter_len',
#        'has_question_mark', 'has_question_mark_t-1', 'utter_t-3', 'utter_t-2',
#        'utter_t-1', 'vocab', 'vocab_t-3', 'vocab_t-2', 'vocab_t-1'],
#       dtype='object')

# %%
df = data.results_to_df(results)
RESULTS_MASK = ['utter_t-3', 'utter_t-2', 'utter_t-1', 'polarity', 'vocab_t-3', 'vocab_t-2', 'vocab_t-1']
new_cols = RESULTS_MASK + list(df.columns)
df = pd.concat([train[ACT_MASK][RESULTS_MASK].reset_index(drop=True), df], ignore_index=True, axis=1)
df.columns = new_cols

y_pred = df[['anger', 'disgust', 'fear', 'happiness', 'no_emotion', 'sadness', 'surprise']].idxmax(axis=1)

# %% [markdown]
# ##### When I misclassify happy or sad as 'no_emotion' what am I missing?

# %%
df[(y_pred == 'no_emotion') & (df['y_true'].isin({'happiness', 'sadness'}))]
# Out:
#                                                utter_t-3  \
# 5          I swear , I ’ m going to kill you for this .
# 6       What ’ s wrong ? Didn ’ t you think it was fu...
# 16      According to some studies it may cause cancer .
# 20     Would you like to take a look at the menu , si...
# 22        Would you care for a drink before you order ?
# 24                      Could I have my bill , please ?
# 27                 Is everything to your satisfaction ?
# 33                Dahua's Market . How can I help you ?
# 37      We have all shapes , sizes , qualities and pr...
# 40     I think I going to need some iced water too . ...
# 41                 Yes , we charge 50 cents for water .
# 46      Oh , yes , that is a beautiful color . It has...
# 49      Wow , that sounds like a bargain . I'm runnin...
# 50              Golden Taxi cabs , how may I help you ?
# 54                              Hi Bill , it ’ s Jane .
# 58                               Do you accept checks ?
# 71      Me , too . There was always a good round of a...
# 75                             Hello , may I help you ?
# 76      Well , I'm looking for some winter clothes . ...
# 95                                     What's it like ?
# 97                                          Mrs . Sue ?
# 104     Do you have any more skirts in this style ? I...
# 113                      Do the drivers speak English ?
# 114    Diana's Flowers , Diana Lin's office , may I h...
# 140                                Hello , is John in ?
# 141                         May I please speak to Tom ?
# 165       You don ’ t have to explain . Suit yourself .
# 174                            It's time to go to bed .
# 177                           Shall we go out tonight ?
# 178                           Have you got any better ?
# ...                                                  ...
# 58493   Oh , all right . I lost a bunch of money in t...
# 58566                                       Very well .
# 58624                                    There you go .
# 58710                I have a problem with this check .
# 58712    I wrote out a check for $ 100 and it bounced .
# 58717   You only have $ 57 left in your checking acco...
# 58722   Are you sure you have $ 100 in your checking ...
# 58779            Will you be able to solve my problem ?
# 58823                        You owe $ 235.13 in fees .
# 58827                           Very well . Thank you .
# 58829                       Do I have any fees to pay ?
# 58847              You need to keep a minimum balance .
# 58850                                     Is that all ?
# 58853                              How can I help you ?
# 58858     I have another savings account open already .
# 58895   For each time you overdraft , you have to pay...
# 58911                 I have never used an ATM before .
# 58915                                   What ’ s next ?
# 58924                                 What about cash ?
# 58938         This will be my first time using an ATM .
# 58967   That ’ s good idea . You don ’ t need to worr...
# 58999   Yeah , you ’ re right . We aren ’ t getting a...
# 59011                                      What is it ?
# 59051   Our product features inventory tracking softw...
# 59103       Sixty ? That's too much . How can that be ?
# 59107  Welcome to the company . We are conducting a s...
# 59118   Oh , so I don't sign the contract today . Is ...
# 59174   I've got several good reasons . I've been her...
# 59194   Well . According to the contract , we are res...
# 59206            Are you going to make an offer today ?
#
#                                                utter_t-2  \
# 5       What ’ s wrong ? Didn ’ t you think it was fu...
# 6       Oh , yeah ! I had a blast ! I love sweating l...
# 16      Oh , don't let that worry you . If that were ...
# 20                                    Yes . Thank you .
# 22                            A glass of Qingdao beer .
# 24                                    Certainly , sir .
# 27      No , the steak was recommended , but it is no...
# 33                        Where is your store located ?
# 37      I think so . Aren't the four Cs , cut , clari...
# 40                 Yes , we charge 50 cents for water .
# 41      That's fine . Could you give me some more nap...
# 46                              Great , I'll take one .
# 49         I'd be glad to . Do you need anything else ?
# 50                   Can you send a cab to pick me up ?
# 54      Jane , I ’ m on the other line , can you hang...
# 58      No , I'm sorry we don't . We accept credit ca...
# 71      Yes , the applause ! That was what kept wakin...
# 75      Well , I'm looking for some winter clothes . ...
# 76                       Yes , everything is 25 % off .
# 95      It's really fantastic . The hero , Super Warr...
# 97                                                Yes ?
# 104     I'm sorry . I think we're out of this skirt i...
# 113     Some are better than others . But , you shoul...
# 114                                       Is Diana in ?
# 140                         No , can I take a message ?
# 141                             Tom has gone to lunch .
# 165     I apologize . You have my word , I ’ ll spend...
# 174               But mum , we're watching this movie .
# 177                       Yeah , let's go Joe's Disco .
# 178                          That's the best there is .
# ...                                                  ...
# 58493   Yeah . I lost money investing in the Internet...
# 58566                 Do you need help with something ?
# 58624                           Do you want cash back ?
# 58710                                  What ’ s wrong ?
# 58712   Do you have enough money in your checking acc...
# 58717                             That ’ s impossible .
# 58722                                 I thought I did .
# 58779          I ’ m going to cancel the fees you owe .
# 58823                          I can ’ t believe that .
# 58827                        What can I help you with ?
# 58829                    As a matter of fact , you do .
# 58847                                  How much is it ?
# 58850                      Yes . That ’ s the minimum .
# 58853                  I want to open another account .
# 58858   Do you want to transfer money from that accou...
# 58895                        That ’ s not a small fee .
# 58911                    I can show you how to use it .
# 58915                                  Enter your PIN .
# 58924             I didn ’ t bring cash with me today .
# 58938                        I can help you with that .
# 58967   Yes . My bank offers very good terms and cond...
# 58999   Exactly ! I searched on the web and found a c...
# 59011   Well , the stock market just took a huge plun...
# 59051                   Is the software user-friendly ?
# 59103   I thought it was wrong too . It didn't make s...
# 59107   That's easy . It was your office ergonomics t...
# 59118   I don't want you to misunderstand , Miss Brig...
# 59174   Salaries are confidential , how do you know h...
# 59194   Forty faulty instruments means that 4 % are n...
# 59206   Yes . My customer is in urgent need of the st...
#
#                                                utter_t-1  polarity  \
# 5       Oh , yeah ! I had a blast ! I love sweating l...  0.000000
# 6       Oh , no , get off it . It wasn ’ t such a kil...  0.000000
# 16      I just happen to have a question for you guys...  0.250000
# 20        Would you care for a drink before you order ?   0.000000
# 22      Yes , sir . I'll bring it over . Have you dec...  0.000000
# 24                  I'm afraid there's been a mistake .  -0.350000
# 27      Oh ! Sorry to hear that . This is quite unusu... -0.275000
# 33       We are on Nanjing Road , next to the theatre .   0.285714
# 37      You've got it . Tell me a little bit about wh... -0.100000
# 40      That's fine . Could you give me some more nap...  0.500000
# 41                   Sure . Do you need anything else ?   0.100000
# 46      Have you heard about our special promotion th...  0.033333
# 49      Oh , I almost forgot . It's my mum's birthday...  0.000000
# 50                               Sure , where are you ?   0.000000
# 54                                               Sure .   0.261905
# 58      Well , I don't have any cash with me , I'll h...  0.196429
# 71      And it's been such a faultless performance wi...  0.000000
# 75                       Yes , everything is 25 % off .   0.000000
# 76      Do you have any skirt that will go with this ...  0.253333
# 95                                           And then ?   0.000000
# 97      Mr . Brown will have to call you back in a li...  0.142857
# 104     No , that's all right . I'll just look for so...  0.000000
# 113                                     Are they safe ?   0.633333
# 114     No , she's out for lunch . May I take a messa...  0.000000
# 140                         No , I'll call back later .   0.285714
# 141                           I'll just try him again .   0.000000
# 165                                       We ’ ll see .   0.000000
# 174         I don't care , it's school in the morning .   0.500000
# 177                         We'd better ask dad first .   0.500000
# 178                              Okay , I'll take one .   0.000000
# ...                                                  ...       ...
# 58493   Just goes to show that you should buy compani...  0.700000
# 58566                       I need to make a transfer .   0.000000
# 58624                                    Yes , please .   0.200000
# 58710    I wrote out a check for $ 100 and it bounced .   0.000000
# 58712                                    I believe so .   0.000000
# 58717   I ’ m sorry , but that ’ s what our records s...  0.433333
# 58722                            I ’ ll check for you .   0.260000
# 58779            So , I don ’ t have to pay any of it ?   0.000000
# 58823          When will you be paying these fees off ?   0.285714
# 58827                       Do I have any fees to pay ?   0.000000
# 58829                                        How much ?   0.000000
# 58847         You need at least $ 100 in your account .   0.000000
# 58850   What happens if I don ’ t meet that requireme...  0.416667
# 58853                What kind would you like to open ?   0.000000
# 58858                         I would like to do that .   0.200000
# 58895                       You shouldn ’ t overdraft .   0.500000
# 58911                                 How do I use it ?   0.000000
# 58915                       What else do I have to do ?   0.000000
# 58924   I ’ m sorry , but you can ’ t take the items ...  0.000000
# 58938                     Explain to me how to use it .   0.000000
# 58967   I have a deposit account with my bank . There...  0.416667
# 58999   Sounds good , although , do you think we can ...  0.416667
# 59011                What do you mean ? What happened ?   0.147778
# 59051   Yes it is very easy to use and each system in...  0.000000
# 59103   Just two days ago it was 35 . How can it be 6...  0.200000
# 59107    You're kidding ! Something as simple as that ?   0.090000
# 59118                               I can accept that .   0.700000
# 59174   Well , I've noticed all the new cars around h...  0.433333
# 59194   I am sorry about the quality problem , but I ...  0.267857
# 59206              Ok , I'll get this rate right away .   0.000000
#
#                                                vocab_t-3  \
# 5      ROOT_swear_ROOTPOS_VERB_POS_PRON_DEP_nsubj*^RO...
# 6      ROOT_s_ROOTPOS_VERB_POS_NOUN_DEP_nsubj*^ROOT_t...
# 16     ROOT_cause_ROOTPOS_VERB_POS_NOUN_DEP_pobj*^ROO...
# 20     ROOT_like_ROOTPOS_VERB_POS_PRON_DEP_nsubj*^ROO...
# 22     ROOT_care_ROOTPOS_VERB_POS_PRON_DEP_nsubj*^ROO...
# 24     ROOT_have_ROOTPOS_VERB_POS_PRON_DEP_nsubj*^ROO...
# 27     ROOT_Is_ROOTPOS_VERB_POS_NOUN_DEP_nsubj*^ROOT_...
# 33     ROOT_help_ROOTPOS_VERB_POS_PRON_DEP_nsubj*^ROO...
# 37     ROOT_know_ROOTPOS_VERB_POS_PRON_DEP_nsubj*^ROO...
# 40     ROOT_think_ROOTPOS_VERB_POS_PRON_DEP_nsubj*^RO...
# 41     ROOT_charge_ROOTPOS_VERB_POS_PRON_DEP_nsubj*^R...
# 46     ROOT_is_ROOTPOS_VERB_POS_DET_DEP_nsubj*^ROOT_b...
# 49     ROOT_sounds_ROOTPOS_VERB_POS_DET_DEP_nsubj*^RO...
# 50     ROOT_help_ROOTPOS_VERB_POS_PRON_DEP_nsubj*^ROO...
# 54     LEMMA_hi*^LEMMA_bill*^LEMMA_,*^LEMMA_-PRON-*^L...
# 58     ROOT_accept_ROOTPOS_VERB_POS_PRON_DEP_nsubj*^R...
# 71     ROOT_was_ROOTPOS_VERB_POS_NOUN_DEP_pobj*^ROOT_...
# 75     ROOT_help_ROOTPOS_VERB_POS_PRON_DEP_nsubj*^ROO...
# 76     ROOT_looking_ROOTPOS_VERB_POS_PRON_DEP_nsubj*^...
# 95     ROOT_'s_ROOTPOS_VERB_POS_PRON_DEP_nsubj*^LEMMA...
# 97     LEMMA_mrs*^LEMMA_.*^LEMMA_sue*^LEMMA_?*^LEMMA_...
# 104    ROOT_have_ROOTPOS_VERB_POS_PRON_DEP_nsubj*^ROO...
# 113    ROOT_speak_ROOTPOS_VERB_POS_NOUN_DEP_nsubj*^RO...
# 114    ROOT_help_ROOTPOS_VERB_POS_NOUN_DEP_nsubj*^ROO...
# 140    ROOT_is_ROOTPOS_VERB_POS_PROPN_DEP_nsubj*^LEMM...
# 141    ROOT_speak_ROOTPOS_VERB_POS_PRON_DEP_nsubj*^RO...
# 165    ROOT_don_ROOTPOS_VERB_POS_PRON_DEP_nsubj*^LEMM...
# 174    ROOT_'s_ROOTPOS_VERB_POS_PRON_DEP_nsubj*^ROOT_...
# 177    ROOT_go_ROOTPOS_VERB_POS_PRON_DEP_nsubj*^LEMMA...
# 178    ROOT_got_ROOTPOS_VERB_POS_PRON_DEP_nsubj*^LEMM...
# ...                                                  ...
# 58493  ROOT_lost_ROOTPOS_VERB_POS_PRON_DEP_nsubj*^ROO...
# 58566  LEMMA_ *^LEMMA_very*^LEMMA_well*^LEMMA_.*^LEMM...
# 58624  ROOT_go_ROOTPOS_VERB_POS_PRON_DEP_nsubj*^LEMMA...
# 58710  ROOT_have_ROOTPOS_VERB_POS_PRON_DEP_nsubj*^ROO...
# 58712  ROOT_wrote_ROOTPOS_VERB_POS_PRON_DEP_nsubj*^RO...
# 58717  ROOT_have_ROOTPOS_VERB_POS_PRON_DEP_nsubj*^ROO...
# 58722  ROOT_Are_ROOTPOS_VERB_POS_PRON_DEP_nsubj*^ROOT...
# 58779  ROOT_be_ROOTPOS_VERB_POS_PRON_DEP_nsubj*^ROOT_...
# 58823  ROOT_owe_ROOTPOS_VERB_POS_PRON_DEP_nsubj*^ROOT...
# 58827  ROOT_Thank_ROOTPOS_VERB_POS_PRON_DEP_dobj*^LEM...
# 58829  ROOT_have_ROOTPOS_VERB_POS_PRON_DEP_nsubj*^ROO...
# 58847  ROOT_need_ROOTPOS_VERB_POS_PRON_DEP_nsubj*^ROO...
# 58850  ROOT_Is_ROOTPOS_VERB_POS_ADV_DEP_nsubj*^LEMMA_...
# 58853  ROOT_help_ROOTPOS_VERB_POS_PRON_DEP_nsubj*^ROO...
# 58858  ROOT_have_ROOTPOS_VERB_POS_PRON_DEP_nsubj*^ROO...
# 58895  ROOT_have_ROOTPOS_VERB_POS_NOUN_DEP_pobj*^ROOT...
# 58911  ROOT_used_ROOTPOS_VERB_POS_PRON_DEP_nsubj*^ROO...
# 58915  LEMMA_ *^LEMMA_what*^LEMMA_'*^LEMMA_s*^LEMMA_n...
# 58924  ROOT_about_ROOTPOS_ADP_POS_NOUN_DEP_pobj*^LEMM...
# 58938  ROOT_be_ROOTPOS_VERB_POS_DET_DEP_nsubj*^ROOT_b...
# 58967  ROOT_’_ROOTPOS_PUNCT_POS_DET_DEP_nsubj*^ROOT_d...
# 58999  ROOT_re_ROOTPOS_VERB_POS_VERB_DEP_nsubj*^ROOT_...
# 59011  ROOT_is_ROOTPOS_VERB_POS_PRON_DEP_nsubj*^LEMMA...
# 59051  ROOT_features_ROOTPOS_VERB_POS_NOUN_DEP_nsubj*...
# 59103  ROOT_'s_ROOTPOS_VERB_POS_DET_DEP_nsubj*^ROOT_b...
# 59107  ROOT_Welcome_ROOTPOS_VERB_POS_NOUN_DEP_pobj*^R...
# 59118  ROOT_sign_ROOTPOS_VERB_POS_PRON_DEP_nsubj*^ROO...
# 59174  ROOT_got_ROOTPOS_VERB_POS_PRON_DEP_nsubj*^ROOT...
# 59194  ROOT_are_ROOTPOS_VERB_POS_NOUN_DEP_pobj*^ROOT_...
# 59206  ROOT_going_ROOTPOS_VERB_POS_PRON_DEP_nsubj*^RO...
#
#                                                vocab_t-2  \
# 5      ROOT_s_ROOTPOS_VERB_POS_NOUN_DEP_nsubj*^ROOT_t...
# 6      ROOT_had_ROOTPOS_VERB_POS_PRON_DEP_nsubj*^ROOT...
# 16     ROOT_let_ROOTPOS_VERB_POS_DET_DEP_nsubj*^ROOT_...
# 20     ROOT_Thank_ROOTPOS_VERB_POS_PRON_DEP_dobj*^LEM...
# 22     ROOT_glass_ROOTPOS_NOUN_POS_NOUN_DEP_pobj*^LEM...
# 24     LEMMA_ *^LEMMA_certainly*^LEMMA_,*^LEMMA_sir*^...
# 27     ROOT_recommended_ROOTPOS_VERB_POS_PRON_DEP_nsu...
# 33     LEMMA_ *^LEMMA_where*^LEMMA_be*^LEMMA_-PRON-*^...
# 37     ROOT_think_ROOTPOS_VERB_POS_PRON_DEP_nsubj*^RO...
# 40     ROOT_charge_ROOTPOS_VERB_POS_PRON_DEP_nsubj*^R...
# 41     ROOT_'s_ROOTPOS_VERB_POS_DET_DEP_nsubj*^ROOT_g...
# 46     ROOT_take_ROOTPOS_VERB_POS_PRON_DEP_nsubj*^ROO...
# 49     ROOT_be_ROOTPOS_VERB_POS_PRON_DEP_nsubj*^ROOT_...
# 50     ROOT_send_ROOTPOS_VERB_POS_PRON_DEP_nsubj*^ROO...
# 54     ROOT_’_ROOTPOS_VERB_POS_PRON_DEP_nsubj*^ROOT_h...
# 58     ROOT_'m_ROOTPOS_VERB_POS_PRON_DEP_nsubj*^ROOT_...
# 71     ROOT_was_ROOTPOS_VERB_POS_DET_DEP_nsubj*^ROOT_...
# 75     ROOT_looking_ROOTPOS_VERB_POS_PRON_DEP_nsubj*^...
# 76     ROOT_is_ROOTPOS_VERB_POS_NOUN_DEP_nsubj*^LEMMA...
# 95     ROOT_'s_ROOTPOS_VERB_POS_PRON_DEP_nsubj*^ROOT_...
# 97     LEMMA_ *^LEMMA_yes*^LEMMA_?*^LEMMA_ *^LEMMA_ye...
# 104    ROOT_'m_ROOTPOS_VERB_POS_PRON_DEP_nsubj*^ROOT_...
# 113    ROOT_are_ROOTPOS_VERB_POS_DET_DEP_nsubj*^ROOT_...
# 114    LEMMA_ *^LEMMA_be*^LEMMA_diana*^LEMMA_in*^LEMM...
# 140    ROOT_take_ROOTPOS_VERB_POS_PRON_DEP_nsubj*^ROO...
# 141    ROOT_gone_ROOTPOS_VERB_POS_PROPN_DEP_nsubj*^RO...
# 165    ROOT_apologize_ROOTPOS_VERB_POS_PRON_DEP_nsubj...
# 174    ROOT_watching_ROOTPOS_VERB_POS_PRON_DEP_nsubj*...
# 177    ROOT_let_ROOTPOS_VERB_POS_INTJ_DEP_nsubj*^ROOT...
# 178    ROOT_is_ROOTPOS_VERB_POS_DET_DEP_nsubj*^LEMMA_...
# ...                                                  ...
# 58493  ROOT_lost_ROOTPOS_VERB_POS_PRON_DEP_nsubj*^ROO...
# 58566  ROOT_need_ROOTPOS_VERB_POS_PRON_DEP_nsubj*^ROO...
# 58624  ROOT_want_ROOTPOS_VERB_POS_PRON_DEP_nsubj*^ROO...
# 58710  ROOT_s_ROOTPOS_VERB_POS_NOUN_DEP_nsubj*^LEMMA_...
# 58712  ROOT_have_ROOTPOS_VERB_POS_PRON_DEP_nsubj*^ROO...
# 58717  ROOT_s_ROOTPOS_VERB_POS_DET_DEP_nsubj*^LEMMA_ ...
# 58722  ROOT_thought_ROOTPOS_VERB_POS_PRON_DEP_nsubj*^...
# 58779  ROOT_going_ROOTPOS_VERB_POS_VERB_DEP_nsubj*^RO...
# 58823  ROOT_believe_ROOTPOS_VERB_POS_PRON_DEP_nsubj*^...
# 58827  ROOT_help_ROOTPOS_VERB_POS_NOUN_DEP_dobj*^ROOT...
# 58829  ROOT_do_ROOTPOS_VERB_POS_NOUN_DEP_pobj*^ROOT_d...
# 58847  ROOT_is_ROOTPOS_VERB_POS_PRON_DEP_nsubj*^LEMMA...
# 58850  ROOT_s_ROOTPOS_VERB_POS_PUNCT_DEP_nsubj*^LEMMA...
# 58853  ROOT_want_ROOTPOS_VERB_POS_PRON_DEP_nsubj*^ROO...
# 58858  ROOT_want_ROOTPOS_VERB_POS_PRON_DEP_nsubj*^ROO...
# 58895  ROOT_s_ROOTPOS_VERB_POS_DET_DEP_nsubj*^ROOT_s_...
# 58911  ROOT_show_ROOTPOS_VERB_POS_PRON_DEP_nsubj*^ROO...
# 58915  ROOT_Enter_ROOTPOS_VERB_POS_NOUN_DEP_dobj*^LEM...
# 58924  ROOT_didn_ROOTPOS_VERB_POS_PRON_DEP_nsubj*^ROO...
# 58938  ROOT_help_ROOTPOS_VERB_POS_PRON_DEP_nsubj*^ROO...
# 58967  ROOT_offers_ROOTPOS_VERB_POS_NOUN_DEP_nsubj*^R...
# 58999  ROOT_searched_ROOTPOS_VERB_POS_PRON_DEP_nsubj*...
# 59011  ROOT_took_ROOTPOS_VERB_POS_NOUN_DEP_nsubj*^ROO...
# 59051  LEMMA_ *^LEMMA_be*^LEMMA_the*^LEMMA_software*^...
# 59103  ROOT_thought_ROOTPOS_VERB_POS_PRON_DEP_nsubj*^...
# 59107  ROOT_'s_ROOTPOS_VERB_POS_DET_DEP_nsubj*^ROOT_w...
# 59118  ROOT_want_ROOTPOS_VERB_POS_PRON_DEP_nsubj*^ROO...
# 59174  ROOT_are_ROOTPOS_VERB_POS_NOUN_DEP_nsubj*^ROOT...
# 59194  ROOT_means_ROOTPOS_VERB_POS_NOUN_DEP_nsubj*^RO...
# 59206  ROOT_is_ROOTPOS_VERB_POS_NOUN_DEP_nsubj*^ROOT_...
#
#                                                vocab_t-1     y_true  anger  \
# 5      ROOT_had_ROOTPOS_VERB_POS_PRON_DEP_nsubj*^ROOT...  happiness    0.0
# 6      ROOT_get_ROOTPOS_VERB_POS_PRON_DEP_pobj*^ROOT_...  happiness    0.0
# 16     ROOT_happen_ROOTPOS_VERB_POS_PRON_DEP_nsubj*^R...  happiness    0.0
# 20     ROOT_care_ROOTPOS_VERB_POS_PRON_DEP_nsubj*^ROO...    sadness    0.1
# 22     ROOT_bring_ROOTPOS_VERB_POS_PRON_DEP_nsubj*^RO...  happiness    0.0
# 24     ROOT_'m_ROOTPOS_VERB_POS_PRON_DEP_nsubj*^LEMMA...  happiness    0.0
# 27     ROOT_Sorry_ROOTPOS_INTJ_POS_DET_DEP_dobj*^ROOT...  happiness    0.0
# 33     ROOT_are_ROOTPOS_VERB_POS_PRON_DEP_nsubj*^ROOT...  happiness    0.0
# 37     ROOT_got_ROOTPOS_VERB_POS_PRON_DEP_nsubj*^ROOT...  happiness    0.0
# 40     ROOT_'s_ROOTPOS_VERB_POS_DET_DEP_nsubj*^ROOT_g...  happiness    0.0
# 41     ROOT_need_ROOTPOS_VERB_POS_PRON_DEP_nsubj*^ROO...  happiness    0.0
# 46     ROOT_heard_ROOTPOS_VERB_POS_PRON_DEP_nsubj*^RO...  happiness    0.0
# 49     ROOT_forgot_ROOTPOS_VERB_POS_PRON_DEP_nsubj*^R...  happiness    0.0
# 50     ROOT_Sure_ROOTPOS_PROPN_POS_PRON_DEP_nsubj*^LE...    sadness    0.0
# 54     LEMMA_ *^LEMMA_sure*^LEMMA_.*^LEMMA_ *^LEMMA_s...  happiness    0.0
# 58     ROOT_have_ROOTPOS_VERB_POS_PRON_DEP_nsubj*^ROO...    sadness    0.1
# 71     ROOT_been_ROOTPOS_VERB_POS_NOUN_DEP_pobj*^LEMM...    sadness    0.0
# 75     ROOT_is_ROOTPOS_VERB_POS_NOUN_DEP_nsubj*^LEMMA...    sadness    0.0
# 76     ROOT_have_ROOTPOS_VERB_POS_PRON_DEP_nsubj*^ROO...    sadness    0.0
# 95     LEMMA_ *^LEMMA_and*^LEMMA_then*^LEMMA_?*^LEMMA...    sadness    0.0
# 97     ROOT_have_ROOTPOS_VERB_POS_PROPN_DEP_nsubj*^RO...    sadness    0.1
# 104    ROOT_'s_ROOTPOS_VERB_POS_DET_DEP_nsubj*^ROOT_l...  happiness    0.0
# 113    ROOT_Are_ROOTPOS_VERB_POS_PRON_DEP_nsubj*^LEMM...  happiness    0.0
# 114    ROOT_'s_ROOTPOS_VERB_POS_PRON_DEP_nsubj*^ROOT_...  happiness    0.0
# 140    ROOT_call_ROOTPOS_VERB_POS_PRON_DEP_nsubj*^LEM...  happiness    0.0
# 141    ROOT_try_ROOTPOS_VERB_POS_PRON_DEP_nsubj*^ROOT...  happiness    0.0
# 165    ROOT_see_ROOTPOS_VERB_POS_PRON_DEP_nsubj*^LEMM...  happiness    0.0
# 174    ROOT_'s_ROOTPOS_VERB_POS_PRON_DEP_nsubj*^ROOT_...  happiness    0.0
# 177    ROOT_ask_ROOTPOS_VERB_POS_PRON_DEP_nsubj*^ROOT...  happiness    0.0
# 178    ROOT_take_ROOTPOS_VERB_POS_PRON_DEP_nsubj*^ROO...  happiness    0.0
# ...                                                  ...        ...    ...
# 58493  ROOT_goes_ROOTPOS_VERB_POS_PRON_DEP_nsubj*^ROO...  happiness    0.0
# 58566  ROOT_need_ROOTPOS_VERB_POS_PRON_DEP_nsubj*^ROO...  happiness    0.0
# 58624  LEMMA_ *^LEMMA_yes*^LEMMA_,*^LEMMA_please*^LEM...  happiness    0.0
# 58710  ROOT_wrote_ROOTPOS_VERB_POS_PRON_DEP_nsubj*^RO...  happiness    0.0
# 58712  ROOT_believe_ROOTPOS_VERB_POS_PRON_DEP_nsubj*^...  happiness    0.0
# 58717  ROOT_’_ROOTPOS_VERB_POS_PRON_DEP_nsubj*^ROOT_s...  happiness    0.0
# 58722  ROOT_check_ROOTPOS_VERB_POS_PRON_DEP_nsubj*^RO...  happiness    0.0
# 58779  ROOT_don_ROOTPOS_VERB_POS_PRON_DEP_nsubj*^ROOT...    sadness    0.1
# 58823  ROOT_paying_ROOTPOS_VERB_POS_PRON_DEP_nsubj*^R...  happiness    0.0
# 58827  ROOT_have_ROOTPOS_VERB_POS_PRON_DEP_nsubj*^ROO...  happiness    0.0
# 58829  LEMMA_ *^LEMMA_how*^LEMMA_much*^LEMMA_?*^LEMMA...  happiness    0.0
# 58847  ROOT_need_ROOTPOS_VERB_POS_PRON_DEP_nsubj*^ROO...  happiness    0.0
# 58850  ROOT_happens_ROOTPOS_VERB_POS_NOUN_DEP_nsubj*^...  happiness    0.0
# 58853  ROOT_like_ROOTPOS_VERB_POS_NOUN_DEP_dobj*^ROOT...  happiness    0.0
# 58858  ROOT_like_ROOTPOS_VERB_POS_PRON_DEP_nsubj*^ROO...  happiness    0.0
# 58895  ROOT_shouldn_ROOTPOS_VERB_POS_PRON_DEP_nsubj*^...  happiness    0.0
# 58911  ROOT_use_ROOTPOS_VERB_POS_PRON_DEP_nsubj*^ROOT...  happiness    0.1
# 58915  ROOT_have_ROOTPOS_VERB_POS_NOUN_DEP_dobj*^ROOT...  happiness    0.0
# 58924  ROOT_’_ROOTPOS_VERB_POS_PRON_DEP_nsubj*^ROOT_s...  happiness    0.0
# 58938  ROOT_Explain_ROOTPOS_PROPN_POS_PRON_DEP_pobj*^...  happiness    0.0
# 58967  ROOT_have_ROOTPOS_VERB_POS_PRON_DEP_nsubj*^ROO...  happiness    0.0
# 58999  ROOT_Sounds_ROOTPOS_VERB_POS_PRON_DEP_nsubj*^R...  happiness    0.0
# 59011  ROOT_mean_ROOTPOS_VERB_POS_NOUN_DEP_dobj*^ROOT...  happiness    0.0
# 59051  ROOT_is_ROOTPOS_VERB_POS_PRON_DEP_nsubj*^ROOT_...  happiness    0.0
# 59103  ROOT_was_ROOTPOS_VERB_POS_PRON_DEP_nsubj*^ROOT...  happiness    0.0
# 59107  ROOT_kidding_ROOTPOS_VERB_POS_PRON_DEP_nsubj*^...    sadness    0.0
# 59118  ROOT_accept_ROOTPOS_VERB_POS_PRON_DEP_nsubj*^R...  happiness    0.0
# 59174  ROOT_noticed_ROOTPOS_VERB_POS_PRON_DEP_nsubj*^...  happiness    0.0
# 59194  ROOT_am_ROOTPOS_VERB_POS_PRON_DEP_nsubj*^ROOT_...  happiness    0.0
# 59206  ROOT_get_ROOTPOS_VERB_POS_PRON_DEP_nsubj*^ROOT...  happiness    0.0
#
#        disgust  fear  happiness  no_emotion  sadness  surprise
# 5          0.0   0.0   0.200000    0.800000      0.0       0.0
# 6          0.0   0.0   0.100000    0.900000      0.0       0.0
# 16         0.0   0.0   0.100000    0.900000      0.0       0.0
# 20         0.0   0.0   0.000000    0.900000      0.0       0.0
# 22         0.0   0.0   0.100000    0.900000      0.0       0.0
# 24         0.0   0.0   0.100000    0.900000      0.0       0.0
# 27         0.0   0.0   0.000000    1.000000      0.0       0.0
# 33         0.0   0.0   0.100000    0.900000      0.0       0.0
# 37         0.0   0.0   0.200000    0.800000      0.0       0.0
# 40         0.0   0.0   0.166667    0.833333      0.0       0.0
# 41         0.0   0.0   0.100000    0.900000      0.0       0.0
# 46         0.0   0.0   0.100000    0.800000      0.0       0.1
# 49         0.0   0.0   0.100000    0.900000      0.0       0.0
# 50         0.0   0.0   0.000000    1.000000      0.0       0.0
# 54         0.0   0.0   0.200000    0.700000      0.0       0.1
# 58         0.0   0.0   0.100000    0.800000      0.0       0.0
# 71         0.0   0.0   0.000000    1.000000      0.0       0.0
# 75         0.0   0.0   0.100000    0.900000      0.0       0.0
# 76         0.0   0.0   0.000000    1.000000      0.0       0.0
# 95         0.0   0.0   0.000000    1.000000      0.0       0.0
# 97         0.0   0.0   0.000000    0.900000      0.0       0.0
# 104        0.0   0.0   0.300000    0.600000      0.0       0.1
# 113        0.0   0.0   0.100000    0.900000      0.0       0.0
# 114        0.0   0.0   0.100000    0.900000      0.0       0.0
# 140        0.0   0.0   0.200000    0.800000      0.0       0.0
# 141        0.0   0.0   0.100000    0.900000      0.0       0.0
# 165        0.0   0.0   0.100000    0.900000      0.0       0.0
# 174        0.0   0.0   0.200000    0.800000      0.0       0.0
# 177        0.0   0.0   0.100000    0.800000      0.1       0.0
# 178        0.0   0.0   0.100000    0.900000      0.0       0.0
# ...        ...   ...        ...         ...      ...       ...
# 58493      0.0   0.0   0.100000    0.900000      0.0       0.0
# 58566      0.0   0.0   0.000000    1.000000      0.0       0.0
# 58624      0.0   0.0   0.100000    0.900000      0.0       0.0
# 58710      0.0   0.0   0.100000    0.900000      0.0       0.0
# 58712      0.0   0.0   0.200000    0.800000      0.0       0.0
# 58717      0.0   0.0   0.000000    1.000000      0.0       0.0
# 58722      0.0   0.0   0.100000    0.900000      0.0       0.0
# 58779      0.0   0.0   0.300000    0.600000      0.0       0.0
# 58823      0.0   0.0   0.200000    0.800000      0.0       0.0
# 58827      0.0   0.0   0.000000    1.000000      0.0       0.0
# 58829      0.0   0.0   0.100000    0.800000      0.0       0.1
# 58847      0.0   0.0   0.000000    0.900000      0.0       0.1
# 58850      0.0   0.0   0.200000    0.800000      0.0       0.0
# 58853      0.0   0.0   0.100000    0.900000      0.0       0.0
# 58858      0.0   0.0   0.200000    0.800000      0.0       0.0
# 58895      0.0   0.0   0.100000    0.900000      0.0       0.0
# 58911      0.0   0.0   0.100000    0.800000      0.0       0.0
# 58915      0.0   0.0   0.100000    0.900000      0.0       0.0
# 58924      0.0   0.0   0.200000    0.800000      0.0       0.0
# 58938      0.0   0.0   0.200000    0.800000      0.0       0.0
# 58967      0.0   0.0   0.300000    0.600000      0.1       0.0
# 58999      0.0   0.0   0.200000    0.800000      0.0       0.0
# 59011      0.0   0.0   0.000000    1.000000      0.0       0.0
# 59051      0.0   0.0   0.180000    0.620000      0.2       0.0
# 59103      0.0   0.0   0.200000    0.800000      0.0       0.0
# 59107      0.0   0.0   0.300000    0.700000      0.0       0.0
# 59118      0.0   0.0   0.100000    0.800000      0.0       0.1
# 59174      0.0   0.0   0.400000    0.500000      0.0       0.1
# 59194      0.0   0.0   0.100000    0.900000      0.0       0.0
# 59206      0.0   0.0   0.000000    1.000000      0.0       0.0
#
# [8171 rows x 15 columns]

# %% [markdown]
# ### Feedback from Orson

# %% [markdown]
# - Difference in distribution of features like:
#     - Word Length
#     - Noun Count
#     - Verb Count
#     - Etc.
# -
